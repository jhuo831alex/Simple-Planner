# %%
import Main

# %% [markdown]
# ### Test Add_Event function with only task name, no time, no priority level, no notes

# %%
Main.main()
# Out:
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)add
# What task would you like to add? Do project
# Would you like to be reminded on a day? (y/n)n
# Would you like to set a priority? (y/n)n
# Would you like to add notes? (y/n)n
# Reminder
#
# ----------[1]----------
# Do project
#
#
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)quit
# Byebye.

# %% [markdown]
# ### Test Add_Event function with a task name, correct time, no priority level, no notes

# %%
Main.main()
# Out:
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)add
# What task would you like to add? Do homework1
# Would you like to be reminded on a day? (y/n)y
# What time would you like to be reminded? (ex: 05/01/2018 23:01)05/01/2018 23:01
# Would you like to set a priority? (y/n)n
# Would you like to add notes? (y/n)n
# Reminder
#
# ----------[1]----------
# Do project
#
# ----------[2]----------
# Do homework1
# 2018-05-01 23:01:00
#
#
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)quit
# Byebye.

# %% [markdown]
# ### Test Add_Event function with a task name, incorrect time, correct priority level, no notes

# %%
Main.main()
# Out:
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)add
# What task would you like to add? Do homework2
# Would you like to be reminded on a day? (y/n)y
# What time would you like to be reminded? (ex: 05/01/2018 23:01)10202018
# Invalid date format. Please refer to example.
# What time would you like to be reminded? (ex: 05/01/2018 23:01)10/20/2018 11:00
# Would you like to set a priority? (y/n)y
# Which priority level would you like to assign to this task? (*/**/***)**
# Would you like to add notes? (y/n)n
# Reminder
#
# ----------[1]----------
# Do project
#
# ----------[2]----------
# Do homework1
# 2018-05-01 23:01:00
#
# ----------[3]----------
# ** Do homework2
# 2018-10-20 11:00:00
#
#
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)quit
# Byebye.

# %% [markdown]
# ### Test Add_Event function with a task name, correct time, incorrect priority level, notes

# %%
Main.main()
# Out:
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)add
# What task would you like to add? Review for tools quiz
# Would you like to be reminded on a day? (y/n)y
# What time would you like to be reminded? (ex: 05/01/2018 23:01)11/11/2019 11:00
# Would you like to set a priority? (y/n)y
# Which priority level would you like to assign to this task? (*/**/***)first
# Invalid priority level. Please refer to example.
# Which priority level would you like to assign to this task? (*/**/***)***
# Would you like to add notes? (y/n)y
# What notes would you like to add to this task?look at lecture
# Reminder
#
# ----------[1]----------
# Do project
#
# ----------[2]----------
# Do homework1
# 2018-05-01 23:01:00
#
# ----------[3]----------
# ** Do homework2
# 2018-10-20 11:00:00
#
# ----------[4]----------
# *** Review for tools quiz
# 2019-11-11 11:00:00
# look at lecture
#
#
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)quit
# Byebye.

# %% [markdown]
# ### Test Add_Event function with a task name, correct time, correct priority level, notes

# %%
Main.main()
# Out:
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)add
# What task would you like to add? Do laundry
# Would you like to be reminded on a day? (y/n)y
# What time would you like to be reminded? (ex: 05/01/2018 23:01)12/01/2018 23:01
# Would you like to set a priority? (y/n)y
# Which priority level would you like to assign to this task? (*/**/***)*
# Would you like to add notes? (y/n)y
# What notes would you like to add to this task?downstairs
# Reminder
#
# ----------[1]----------
# Do project
#
# ----------[2]----------
# Do homework1
# 2018-05-01 23:01:00
#
# ----------[3]----------
# ** Do homework2
# 2018-10-20 11:00:00
#
# ----------[4]----------
# *** Review for tools quiz
# 2019-11-11 11:00:00
# look at lecture
#
# ----------[5]----------
# * Do laundry
# 2018-12-01 23:01:00
# downstairs
#
#
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)quit
# Byebye.

# %% [markdown]
# ### Test Modify function with a different time(correct format), priority level and notes unchanged

# %%
Main.main()
# Out:
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)modify
# Reminder
#
# ----------[1]----------
# Do project
#
# ----------[2]----------
# Do homework1
# 2018-05-01 23:01:00
#
# ----------[3]----------
# ** Do homework2
# 2018-10-20 11:00:00
#
# ----------[4]----------
# *** Review for tools quiz
# 2019-11-11 11:00:00
# look at lecture
#
# ----------[5]----------
# * Do laundry
# 2018-12-01 23:01:00
# downstairs
#
#
# Which event would you like to modify? (Event number)2
# What feature would you like to change first? (Task/Time/Priority/Notes)time
# What is your new remind time? (ex: 05/01/2018 23:01)11/01/2018 23:01
# Would you like to modify other features of your event? n
# Reminder
#
# ----------[1]----------
# Do project
#
# ----------[2]----------
# Do homework1
# 2018-11-01 23:01:00
#
# ----------[3]----------
# ** Do homework2
# 2018-10-20 11:00:00
#
# ----------[4]----------
# *** Review for tools quiz
# 2019-11-11 11:00:00
# look at lecture
#
# ...

# %% [markdown]
# ### Test Modify function with a different time, different priority level(correct format),but notes unchanged

# %%
Main.main()
# Out:
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)modify
# Reminder
#
# ----------[1]----------
# Do project
#
# ----------[2]----------
# Do homework1
# 2018-11-01 23:01:00
#
# ----------[3]----------
# ** Do homework2
# 2018-10-20 11:00:00
#
# ----------[4]----------
# *** Review for tools quiz
# 2019-11-11 11:00:00
# look at lecture
#
# ----------[5]----------
# * Do laundry
# 2018-12-01 23:01:00
# downstairs
#
#
# Which event would you like to modify? (Event number)3
# What feature would you like to change first? (Task/Time/Priority/Notes)time
# What is your new remind time? (ex: 05/01/2018 23:01)12/12/2018 07:00
# Would you like to modify other features of your event? y
# What feature would you like to change? (Task/Time/Priority/Notes)priority
# What is your new priority?(ex:*/**/***) *
# Would you like to modify other features of your event? n
# Reminder
#
# ----------[1]----------
# Do project
#
# ----------[2]----------
# Do homework1
# 2018-11-01 23:01:00
# ...

# %% [markdown]
# ### Test Modify function with a different time, different priority level(correct format),different notes

# %%
Main.main()
# Out:
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)modify
# Reminder
#
# ----------[1]----------
# Do project
#
# ----------[2]----------
# Do homework1
# 2018-11-01 23:01:00
#
# ----------[3]----------
# * Do homework2
# 2018-12-12 07:00:00
#
# ----------[4]----------
# *** Review for tools quiz
# 2019-11-11 11:00:00
# look at lecture
#
# ----------[5]----------
# * Do laundry
# 2018-12-01 23:01:00
# downstairs
#
#
# Which event would you like to modify? (Event number)4
# What feature would you like to change first? (Task/Time/Priority/Notes)time
# What is your new remind time? (ex: 05/01/2018 23:01)12/05/2018 12:00
# Would you like to modify other features of your event? y
# What feature would you like to change? (Task/Time/Priority/Notes)priority
# What is your new priority?(ex:*/**/***) *
# Would you like to modify other features of your event? y
# What feature would you like to change? (Task/Time/Priority/Notes)notes
# ...

# %% [markdown]
# ### Test Check_Event function with valid task number

# %%
Main.main()
# Out:
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)check
# Reminder
#
# ----------[1]----------
# Do project
#
# ----------[2]----------
# Do homework1
# 2018-11-01 23:01:00
#
# ----------[3]----------
# * Do homework2
# 2018-12-12 07:00:00
#
# ----------[4]----------
# * Review for tools quiz
# 2018-12-05 12:00:00
# look at lecture and past homeworks
#
# ----------[5]----------
# * Do laundry
# 2018-12-01 23:01:00
# downstairs
#
#
# Which task did you complete? (Input task number)1
# Reminder
#
# ----------[1]----------
# Do homework1
# 2018-11-01 23:01:00
#
# ----------[2]----------
# * Do homework2
# 2018-12-12 07:00:00
#
# ----------[3]----------
# * Review for tools quiz
# 2018-12-05 12:00:00
# look at lecture and past homeworks
#
# ----------[4]----------
# * Do laundry
# 2018-12-01 23:01:00
# downstairs
#
#
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)quit
# Byebye.

# %% [markdown]
# ### Test Check_Event function with invalid task number

# %%
Main.main()
# Out:
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)check
# Reminder
#
# ----------[1]----------
# Do homework1
# 2018-11-01 23:01:00
#
# ----------[2]----------
# * Do homework2
# 2018-12-12 07:00:00
#
# ----------[3]----------
# * Review for tools quiz
# 2018-12-05 12:00:00
# look at lecture and past homeworks
#
# ----------[4]----------
# * Do laundry
# 2018-12-01 23:01:00
# downstairs
#
#
# Which task did you complete? (Input task number)6
# Invalid task number. Please refer to example.
# Which task did you complete? (Input task number)1
# Reminder
#
# ----------[1]----------
# * Do homework2
# 2018-12-12 07:00:00
#
# ----------[2]----------
# * Review for tools quiz
# 2018-12-05 12:00:00
# look at lecture and past homeworks
#
# ----------[3]----------
# * Do laundry
# 2018-12-01 23:01:00
# downstairs
#
#
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)quit
# Byebye.

# %% [markdown]
# ### Test Add_Event and Modify functions together

# %%
Main.main()
# Out:
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)add
# What task would you like to add? Registration for class
# Would you like to be reminded on a day? (y/n)y
# What time would you like to be reminded? (ex: 05/01/2018 23:01)11/19/2018 04:00
# Would you like to set a priority? (y/n)y
# Which priority level would you like to assign to this task? (*/**/***)***
# Would you like to add notes? (y/n)n
# Reminder
#
# ----------[1]----------
# * Do homework2
# 2018-12-12 07:00:00
#
# ----------[2]----------
# * Review for tools quiz
# 2018-12-05 12:00:00
# look at lecture and past homeworks
#
# ----------[3]----------
# * Do laundry
# 2018-12-01 23:01:00
# downstairs
#
# ----------[4]----------
# *** Registration for class
# 2018-11-19 04:00:00
#
#
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)modify
# Reminder
#
# ----------[1]----------
# * Do homework2
# 2018-12-12 07:00:00
#
# ----------[2]----------
# * Review for tools quiz
# ...

# %% [markdown]
# ### Test Check_Event and Modify functions together

# %%
Main.main()
# Out:
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)check
# Reminder
#
# ----------[1]----------
# * Do homework2
# 2018-12-12 07:00:00
# upload pdf
#
# ----------[2]----------
# * Review for tools quiz
# 2018-12-05 12:00:00
# look at lecture and past homeworks
#
# ----------[3]----------
# * Do laundry
# 2018-12-01 23:01:00
# downstairs
#
# ----------[4]----------
# *** Registration for class
# 2018-11-19 04:00:00
#
#
# Which task did you complete? (Input task number)2
# Reminder
#
# ----------[1]----------
# * Do homework2
# 2018-12-12 07:00:00
# upload pdf
#
# ----------[2]----------
# * Do laundry
# 2018-12-01 23:01:00
# downstairs
#
# ----------[3]----------
# *** Registration for class
# 2018-11-19 04:00:00
#
#
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)modify
# Reminder
#
# ----------[1]----------
# * Do homework2
# 2018-12-12 07:00:00
# upload pdf
#
# ----------[2]----------
# * Do laundry
# 2018-12-01 23:01:00
# downstairs
#
# ...

# %% [markdown]
# ### Test Add_Event, Modify, and Check_Event functions together

# %%
Main.main()
# Out:
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)add
# What task would you like to add? Pick up package
# Would you like to be reminded on a day? (y/n)y
# What time would you like to be reminded? (ex: 05/01/2018 23:01)09/09/2018 13:00
# Would you like to set a priority? (y/n)n
# Would you like to add notes? (y/n)n
# Reminder
#
# ----------[1]----------
# * Do homework2
# 2018-12-12 07:00:00
# upload pdf
#
# ----------[2]----------
# * Do laundry
# 2018-12-01 23:01:00
# downstairs
#
# ----------[3]----------
# *** Registration for class
# 2018-11-19 04:00:00
# 5 max
#
# ----------[4]----------
# Pick up package
# 2018-09-09 13:00:00
#
#
# What would you like to do? (Add Event/Modify Event/Check Event/Quit)modify
# Reminder
#
# ----------[1]----------
# * Do homework2
# 2018-12-12 07:00:00
# upload pdf
#
# ----------[2]----------
# * Do laundry
# 2018-12-01 23:01:00
# downstairs
#
# ----------[3]----------
# *** Registration for class
# 2018-11-19 04:00:00
# 5 max
#
# ...
